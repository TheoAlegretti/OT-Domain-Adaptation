# %%
# %matplotlib inline

# %% [markdown]
# # Linear OT mapping estimation

# %%
# Author: Remi Flamary <remi.flamary@unice.fr>
#
# License: MIT License

# sphinx_gallery_thumbnail_number = 2
import os
from pathlib import Path

import numpy as np
from matplotlib import pyplot as plt
import ot

# %% [markdown]
# ## Generate data

# %%
n = 1000
d = 2
sigma = .1

rng = np.random.RandomState(42)

# source samples
angles = rng.rand(n, 1) * 2 * np.pi
xs = np.concatenate((np.sin(angles), np.cos(angles)),
                    axis=1) + sigma * rng.randn(n, 2)
xs[:n // 2, 1] += 2


# target samples
anglet = rng.rand(n, 1) * 2 * np.pi
xt = np.concatenate((np.sin(anglet), np.cos(anglet)),
                    axis=1) + sigma * rng.randn(n, 2)
xt[:n // 2, 1] += 2


A = np.array([[1.5, .7], [.7, 1.5]])
b = np.array([[4, 2]])
xt = xt.dot(A) + b

# %% [markdown]
# ## Plot data

# %%
plt.figure(1, (5, 5))
plt.plot(xs[:, 0], xs[:, 1], '+')
plt.plot(xt[:, 0], xt[:, 1], 'o')

# %% [markdown]
# ## Estimate linear mapping and transport

# %%
Ae, be = ot.gaussian.empirical_bures_wasserstein_mapping(xs, xt)

xst = xs.dot(Ae) + be

# %% [markdown]
# ## Plot transported samples

# %%
plt.figure(1, (5, 5))
plt.clf()
plt.plot(xs[:, 0], xs[:, 1], '+')
plt.plot(xt[:, 0], xt[:, 1], 'o')
plt.plot(xst[:, 0], xst[:, 1], '+')

plt.show()

# %% [markdown]
# ## Load image data

# %%
def im2mat(img):
    """Converts and image to matrix (one pixel per line)"""
    return img.reshape((img.shape[0] * img.shape[1], img.shape[2]))


def mat2im(X, shape):
    """Converts back a matrix to an image"""
    return X.reshape(shape)


def minmax(img):
    return np.clip(img, 0, 1)


# Loading images
this_file = os.path.realpath('__file__')
data_path = os.path.join(Path(this_file).parent.parent.parent, 'data')

I1 = plt.imread(os.path.join(data_path, 'ocean_day.jpg')).astype(np.float64) / 256
I2 = plt.imread(os.path.join(data_path, 'ocean_sunset.jpg')).astype(np.float64) / 256


X1 = im2mat(I1)
X2 = im2mat(I2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 19
#      16 this_file = os.path.realpath('__file__')
#      17 data_path = os.path.join(Path(this_file).parent.parent.parent, 'data')
# ---> 19 I1 = plt.imread(os.path.join(data_path, 'ocean_day.jpg')).astype(np.float64) / 256
#      20 I2 = plt.imread(os.path.join(data_path, 'ocean_sunset.jpg')).astype(np.float64) / 256
#      23 X1 = im2mat(I1)
#
# File ~/miniforge3/envs/work/lib/python3.10/site-packages/matplotlib/pyplot.py:2195, in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#
# File ~/miniforge3/envs/work/lib/python3.10/site-packages/matplotlib/image.py:1563, in imread(fname, format)
#    1556 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1557     # Pillow doesn't handle URLs directly.
#    1558     raise ValueError(
#    1559         "Please open the URL for reading and pass the "
#    1560         "result to Pillow, e.g. with "
#    1561         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562         )
# -> 1563 with img_open(fname) as image:
#    1564     return (_pil_png_to_float_array(image)
#    1565             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1566             pil_to_array(image))
#
# File ~/miniforge3/envs/work/lib/python3.10/site-packages/PIL/Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/theoalegretti/Documents/data/ocean_day.jpg'

# %% [markdown]
# ## Estimate mapping and adapt

# %%
mapping = ot.da.LinearTransport()

mapping.fit(Xs=X1, Xt=X2)


xst = mapping.transform(Xs=X1)
xts = mapping.inverse_transform(Xt=X2)

I1t = minmax(mat2im(xst, I1.shape))
I2t = minmax(mat2im(xts, I2.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 mapping = ot.da.LinearTransport()
# ----> 3 mapping.fit(Xs=X1, Xt=X2)
#       6 xst = mapping.transform(Xs=X1)
#       7 xts = mapping.inverse_transform(Xt=X2)
#
# NameError: name 'X1' is not defined

# %% [markdown]
# ## Plot transformed images

# %%
plt.figure(2, figsize=(10, 7))

plt.subplot(2, 2, 1)
plt.imshow(I1)
plt.axis('off')
plt.title('Im. 1')

plt.subplot(2, 2, 2)
plt.imshow(I2)
plt.axis('off')
plt.title('Im. 2')

plt.subplot(2, 2, 3)
plt.imshow(I1t)
plt.axis('off')
plt.title('Mapping Im. 1')

plt.subplot(2, 2, 4)
plt.imshow(I2t)
plt.axis('off')
plt.title('Inverse mapping Im. 2')
